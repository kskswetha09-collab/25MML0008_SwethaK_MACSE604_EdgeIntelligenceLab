# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/number_plate_detection
# !ls
# Out:
# /content/drive/MyDrive/number_plate_detection
# number_plate.yaml  vid-1	vid-2  vid-3.cache
# runs		   vid-1.cache	vid-3  yolov8n.pt

# %%
# !cat number_plate.yaml
# Out:
# path: /content/drive/MyDrive/number_plate_detection
#
# train:
#   - vid-1
#   - vid-2
#
# val:
#   - vid-3
#
# nc: 1
# names: ['number_plate']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.0 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train \
  data=number_plate.yaml \
  model=yolov8n.pt \
  imgsz=640 \
  epochs=50 \
  batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install ultralytics easyocr opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 124.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 31.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/number_plate_detection
# !ls
# Out:
# /content/drive/MyDrive/number_plate_detection
# number_plate.yaml  vid-1	vid-2  vid-3.cache  yolov8n.pt
# runs		   vid-1.cache	vid-3  yolo26n.pt

# %%
# !mv yolo26n.pt number_plate_detector.pt

# %%
# !ls
# Out:
# number_plate_detector.pt  runs	 vid-1.cache  vid-3	   yolov8n.pt
# number_plate.yaml	  vid-1  vid-2	      vid-3.cache

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/number_plate_detection/runs/detect/train3/weights/best.pt')
print(model.names)
# Out:
# {0: 'number_plate'}

# %%
results = model(
    '/content/drive/MyDrive/number_plate_detection/vid-3/frame-150.jpg',
    conf=0.25,
    project='/content/drive/MyDrive/number_plate_detection/runs/detect',
    name='np_correct',
    save=True
)
# Out:
# image 1/1 /content/drive/MyDrive/number_plate_detection/vid-3/frame-150.jpg: 384x640 1 number_plate, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/drive/MyDrive/number_plate_detection/runs/detect/np_correct
